# %%
import pandas as pd
import matplotlib.pyplot as pt

# %%
data=pd.read_csv(r"C:\Users\manoj\Documents\vieo games sale data\Video_Games_Sales_as_at_22_Dec_2016.csv")

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
data=data.head(200)

# %%
platform=data['Platform'].unique()

# %%
print(platform)
# Out:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN']

# %%
count=data['Platform'].value_counts()

# %%
pt.figure(figsize=(10,11))
pt.pie(count,labels=count.index,autopct='%1.1f%%',labeldistance=1.1)

pt.axis('equal')
# Out:
# (-1.099999953917539,
#  1.0999999978055972,
#  -1.0999999703131016,
#  1.0999993916398585)

# %%
genre=data['Genre'].value_counts()

# %%
print(genre)
# Out:
# Genre
# Shooter         36
# Action          34
# Platform        31
# Role-Playing    31
# Racing          16
# Misc            15
# Sports          14
# Simulation       7
# Fighting         7
# Puzzle           6
# Adventure        2
# Strategy         1
# Name: count, dtype: int64

# %%
print(genre.values)
# Out:
# [36 34 31 31 16 15 14  7  7  6  2  1]

# %%
pt.bar(genre.index,genre.values)
pt.xticks(rotation=45)
pt.tight_layout()
